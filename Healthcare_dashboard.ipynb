# %% [markdown]
# # Dashboard on diseases from yeare 1990-2019

# %%
import panel as pn
pn.extension('tabulator')
import hvplot.pandas
import seaborn as sns
import numpy as np
import pandas as pd

# %%
# Import the data 
df=pd.read_csv('annual-number-of-deaths-by-cause.csv')

# %%
df['Year'] = df['Year'].astype(str)

df
# Out:
#            Entity Code  Year Number of executions (Amnesty International)  \
# 0     Afghanistan  AFG  2007                                           15
# 1     Afghanistan  AFG  2008                                           17
# 2     Afghanistan  AFG  2009                                            0
# 3     Afghanistan  AFG  2011                                            2
# 4     Afghanistan  AFG  2012                                           14
# ...           ...  ...   ...                                          ...
# 6888     Zimbabwe  ZWE  2015                                          NaN
# 6889     Zimbabwe  ZWE  2016                                          NaN
# 6890     Zimbabwe  ZWE  2017                                          NaN
# 6891     Zimbabwe  ZWE  2018                                          NaN
# 6892     Zimbabwe  ZWE  2019                                          NaN
#
#       Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# ...

# %%
## Data preprocessing

# %%
columns= ['Entity', 'Code', 'Year',
       'Executions',
       'Meningiti',
       'Alzheimer',
       'Parkinson',
       'Nutritional deficiencies',
       'Malaria',
       'Drowning',
       'Interpersonal violence',
       'Maternal disorders',
       'HIV/AIDS',
       'Drug use disorders',
       'Tuberculosis',
       'Cardiovascular diseases',
       'Lower respiratory infections',
       'Neonatal disorders',
       'Alcohol use disorders',
       'Self-harm',
       'Exposure to forces of nature',
       'Diarrheal diseases',
       'Environmental heat and cold exposure',
       'Neoplasms',
       'Conflict and terrorism',
       'Diabetes mellitus',
       'Chronic kidney disease',
       'Poisonings',
       'Protein-energy malnutrition',
       'Terrorism',
       'Road injuries',
       'Chronic respiratory diseases',
       'Cirrhosis and other chronic liver diseases',
       'Digestive diseases',
       'Fire, heat, and hot substances',
       'Acute hepatitis']

d = dict(zip(df.columns,columns))

df.rename(columns=d,inplace=True)
df = df.groupby(['Year', 'Entity']).sum().reset_index()

# %%
# Scale the data to percentage
df['total']=df.iloc[:, 2:].sum(axis=1)

# %%
for i in range(len(df)):
    row_total = df.iloc[i, 34]
    for j in range(2, 34):
        if pd.notnull(df.iloc[i, j]) and pd.notnull(row_total) and row_total != 0:
            df.iloc[i, j] = round((df.iloc[i, j] * 100) / row_total, 2)
        else:
            df.iloc[i, j] = 0

# %%
df=df.drop(['total'],axis=1)

# %%
# Define panel widgets
# year_slider=pn.widgets.IntSlider(name='year', start=1990,end=int(max(df.Year)),step=1, value=1990)
# year_slider

# %%
## make the dataframe interactive

# %%
#df=df.interactive() ## super important

# %%
## create the first plot

# %%
#panel serve Healthcare_dashboard.ipynb

# %%
import panel as pn

# Create the RadioButtonGroup widget
radio_button_group = pn.widgets.RadioButtonGroup(options=['Year', 'Entity'], value='Year', name='Filter by')


# Define the pipeline function
def pipeline(year=None, entity=None):
    # Apply the filters based on selected values
    filtered_df = df.copy()
    if year:
        filtered_df = filtered_df[filtered_df['Year'] == year]
    if entity:
        filtered_df = filtered_df[filtered_df['Entity'] == entity]
    # Perform further operations on the filtered DataFrame
    # ...
    
    # Return the filtered DataFrame or any other desired output
    return filtered_df

# Define a function to update the pipeline based on widget values
def update_pipeline(event):
    if radio_button_group.value == 'Year':
        year = dropdown_year.value
        entity = None
    elif radio_button_group.value == 'Entity':
        year = None
        entity = dropdown_entity.value
    
    filtered_result = pipeline(year=year, entity=entity)
    # Update the display or perform any further actions with the filtered result
    # ...
    
# Create additional widgets for filtering, such as dropdowns for year and entity
dropdown_year = pn.widgets.Select(name='Year', options=df['Year'].unique().tolist())
dropdown_entity = pn.widgets.Select(name='Entity', options=df['Entity'].unique().tolist())

# Add the event listener to the radio button group
radio_button_group.param.watch(update_pipeline, 'value')

# Create a Panel layout for the widgets
panel_layout = pn.Column(
    radio_button_group,
    dropdown_year,
    dropdown_entity
)

# Display the Panel layout
#panel_layout.show()


panel_layout
# Out:
# Column
#     [0] RadioButtonGroup(name='Filter by', options=['Year', 'Entity'], value='Year')
#     [1] Select(name='Year', options=['1990', '1991', ...], value='1990')
#     [2] Select(name='Entity', options=['Afghanistan', ...], value='Afghanistan')

# %%
def update_pipeline(event):
    if radio_button_group.value == 'Year':
        year = dropdown_year.value
        entity = dropdown_entity.value
    elif radio_button_group.value == 'Entity':
        year = dropdown_year.value
        entity = dropdown_entity.value
    
    filtered_result = pipeline(year=year, entity=entity)
    
   
    
    cause_bar_pipeline = (filtered_result.groupby(['Year', 'Entity']).mean()
                          .reset_index()
                          .melt(id_vars=['Year', 'Entity'], var_name='Cause', value_name='Value'))
    
    cause_bar_plot.data = cause_bar_pipeline
    
    # Update the display or perform any further actions with the filtered result
    # ...

# ...

# Create the initial cause_bar_pipeline DataFrame
cause_bar_pipeline = (df.groupby(['Year', 'Entity']).mean()
                      .reset_index()
                      .melt(id_vars=['Year', 'Entity'], var_name='Cause', value_name='Value'))

palette = sns.color_palette("Set2")
cause_bar_plot2 = cause_bar_pipeline.hvplot.bar(
    x='Cause',
    y='Value',
    groupby=['Year','Entity'],
    stacked=True,
    title='Cause-wise Values',
    xlabel='Cause',
    ylabel='Value',
    width=1000,  # Adjust the width as desired
    height=400,  # Adjust the height as desired
    color=palette
)

# ...

# Add the event listener to the radio button group
radio_button_group.param.watch(update_pipeline, 'value')

# ...
cause_bar_plot2
# Out:
# :DynamicMap   [Year,Entity]
#    :Bars   [Cause]   (Value)

# %%
y_axis_source = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=[
       'Meningiti',
       'Alzheimer',
       'Parkinson',
       'Nutritional deficiencies',
       'Malaria',
       'Drowning',
       'Interpersonal violence',
       'Maternal disorders',
       'HIV/AIDS',
       'Drug use disorders',
       'Tuberculosis',
       'Cardiovascular diseases',
       'Lower respiratory infections',
       'Neonatal disorders',
       'Alcohol use disorders',
       'Self-harm',
       'Exposure to forces of nature',
       'Diarrheal diseases',
       'Environmental heat and cold exposure',
       'Neoplasms',
       'Conflict and terrorism',
       'Diabetes mellitus',
       'Chronic kidney disease',
       'Poisonings',
       'Protein-energy malnutrition',
       'Terrorism',
       'Road injuries',
       'Chronic respiratory diseases',
       'Cirrhosis and other chronic liver diseases',
       'Digestive diseases',
       'Fire, heat, and hot substances',
       'Acute hepatitis'], 
    button_type='success'
)
y_axis_source
# Out:
# RadioButtonGroup(button_type='success', name='Y axis', options=['Meningiti', ...], value='Meningiti')

# %%
# def update_pipeline(event):
#     if radio_button_group.value == 'Year':
#         year = dropdown_year.value
#         entity = dropdown_entity.value
#     elif radio_button_group.value == 'Entity':
#         year = dropdown_year.value
#         entity = dropdown_entity.value
    
#     filtered_result = pipeline(year=year, entity=entity)
    
#     year_pipeline = (filtered_result.groupby(['Year', 'Entity']).mean()
#                      .reset_index()
#                      .melt(id_vars=['Year', 'Entity'], var_name='Cause', value_name='Value'))
    
#     year_plot.data = year_pipeline
    
#     # Update the display or perform any further actions with the filtered result
#     # ...

# # ...
# year_slider = pn.widgets.IntSlider(
#     name='Year',
#     start=1990,
#     end=int(df['Year'].max()),
#     step=1,
#     value=1990
# )

# # Create the event listener for the year slider
# def update_year(event):
#     dropdown_year.value = year_slider.value

# year_slider.param.watch(update_year, 'value')

# # ...

# # Add the year slider to the panel layout
# panel_layout.insert(1, year_slider)
# Create the initial year_pipeline DataFrame
year_pipeline = (df.groupby(['Year', 'Entity']).mean()
                 .reset_index()
                 .melt(id_vars=['Year', 'Entity'], var_name='Cause', value_name='Value'))

year_plot = year_pipeline.hvplot(
    x='Year',
    y='Value',
    groupby=['Entity', 'Cause'],
    stacked=True,
    title='Evolution of Disease',
    xlabel='Year',
    ylabel='Value',
    width=1000,  # Adjust the width as desired
    height=400,  # Adjust the height as desired
    color='purple'
)

# ...

# Add the event listener to the radio button group
radio_button_group.param.watch(update_pipeline, 'value')

year_plot
# Out:
# :DynamicMap   [Entity,Cause]
#    :Curve   [Year]   (Value)

# %%
cause_pipeline = (df.groupby(['Year', 'Entity']).mean()
                 .reset_index()
                 .melt(id_vars=['Year', 'Entity'], var_name='Cause', value_name='Value'))
cause_bar_plot = cause_pipeline.hvplot.bar(
    x='Cause',
    y='Value',
    groupby=['Year','Entity'],
    stacked=True,
    title='Cause-wise Values',
    xlabel='Cause',
    ylabel='Value',
    width=1000,  # Adjust the width as desired
    height=400,  # Adjust the height as desired
    color=palette
)

# ...

# Add the event listener to the radio button group
radio_button_group.param.watch(update_pipeline, 'value')

# ...
cause_bar_plot
# Out:
# :DynamicMap   [Year,Entity]
#    :Bars   [Cause]   (Value)

# %%
template2 = pn.template.FastListTemplate(
    title="Causes of deaths per year", 
    sidebar=[pn.pane.Markdown("# Diseases"), 
             pn.pane.Markdown("#### The Cancer and Deaths Dataset: 1990~2019 Globally is a comprehensive dataset containing information on cancer incidence and mortality rates across the world from 1990 to 2019. The dataset is an excellent resource for researchers, healthcare professionals, and policymakers who are interested in understanding the global burden of cancer and its impact on populations."), 
             pn.pane.PNG('Disease.png', sizing_mode='scale_both'),
   
            ],
    main=[pn.Row(pn.Column(year_plot)), 
          pn.Row(pn.Column(cause_bar_plot))],
    accent_base_color="#499990",
    header_background="#499990",
)
template2.show()
# Out:
# Launching server at http://localhost:60690
